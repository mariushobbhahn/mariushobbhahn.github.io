# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # truth of an argument

# %%
#create some distributions
from scipy.stats import beta, gamma, chi2

x = np.linspace(0,1, 100 +1)
#prior
a_p, b_p = 1.3, 1.3
beta_p = beta.pdf(x, a_p, b_p)

#weak evidence
a_1, b_1 = a_p + 0.2, a_p
beta_1 = beta.pdf(x, a_1, b_1)

#mediocre evidence
a_2, b_2 = a_p + 0.5, a_p
beta_2 = beta.pdf(x, a_2, b_2)

#mediocre mechanism
a_3, b_3 = a_p + 4, a_p
beta_3 = beta.pdf(x, a_3, b_3)

#strong mechanism
a_4, b_4 = a_p + 10, a_p
beta_4 = beta.pdf(x, a_4, b_4)

#mediocre + stronger mechanism
a_5, b_5 = a_p + 10 + 4, a_p
beta_5 = beta.pdf(x, a_5, b_5)

# %%
#plot it
fig, axs = plt.subplots(nrows=2, ncols=3, sharex=False, figsize=(23, 12))

axs[0][0].plot(x, beta_p, label='prior')
axs[0][0].set_yticklabels([])
axs[0][0].set_yticks([])
axs[0][0].legend(prop={'size': 20})

axs[0][1].plot(x, beta_p, label='prior')
axs[0][1].plot(x, beta_1, label='weak evidence')
axs[0][1].set_yticklabels([])
axs[0][1].set_yticks([])
axs[0][1].legend(prop={'size': 20})

axs[0][2].plot(x, beta_p, label='prior')
axs[0][2].plot(x, beta_2, label='mediocre evidence')
axs[0][2].set_yticklabels([])
axs[0][2].set_yticks([])
axs[0][2].legend(prop={'size': 20})

axs[1][0].plot(x, beta_p, label='prior')
axs[1][0].plot(x, beta_3, label='mediocre mechanism')
axs[1][0].set_yticklabels([])
axs[1][0].set_yticks([])
axs[1][0].legend(prop={'size': 18})

axs[1][1].plot(x, beta_p, label='prior')
axs[1][1].plot(x, beta_4, label='stronger mechanism')
axs[1][1].set_yticklabels([])
axs[1][1].set_yticks([])
axs[1][1].legend(prop={'size': 20})

axs[1][2].plot(x, beta_p, label='prior')
axs[1][2].plot(x, beta_5, label='mediocre + stronger mechanism')
axs[1][2].set_yticklabels([])
axs[1][2].set_yticks([])
axs[1][2].legend(prop={'size': 15})

plt.show();

# %% [markdown]
# # impact of an argument

# %%
# create some impact distributions
from scipy.stats import gamma
x_gamma = np.linspace(0, 25, 250+1)

#prior

s= 1
g_p = 2.5
gamma_p = gamma.pdf(x_gamma, g_p, scale=s)

#small impact
g_1 = g_p + 1
gamma_1 = gamma.pdf(x_gamma, g_1, scale=s)

#large effect
g_2 = g_p + 5
gamma_2 = gamma.pdf(x_gamma, g_2, scale=s)

#large group
g_3 = g_p + 7
gamma_3 = gamma.pdf(x_gamma, g_3, scale=s)

#strong moral concideration
g_4 = g_p + 3
gamma_4 = gamma.pdf(x_gamma, g_4, scale=s)

#large group + large effect
g_5 = g_2 + g_3 - g_p
gamma_5 = gamma.pdf(x_gamma, g_5, scale=s)

# %%
#plot it
fig, axs = plt.subplots(nrows=2, ncols=3, sharex=False, figsize=(23, 12))
x_labels = ['', 'nothing happens', 'who cares', 'maybe something', 'actually something', 'big impact', 'nuclear war' ]


axs[0][0].plot(x_gamma, gamma_p, label='prior')
axs[0][0].vlines(g_p*s, ymin=0, ymax=1*gamma_p.max(), linestyle='dashed', alpha=1, color="#1f77b4")
axs[0][0].set_yticklabels([])
axs[0][0].set_yticks([])
axs[0][0].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[0][0].legend(prop={'size': 20})

axs[0][1].plot(x_gamma, gamma_p, label='prior')
axs[0][1].plot(x_gamma, gamma_1, label='small impact')
axs[0][1].vlines(g_p*s, ymin=0, ymax=1*gamma_p.max(), linestyle='dashed', alpha=1, color="#1f77b4")
axs[0][1].vlines(g_1*s, ymin=0, ymax=1*gamma_1.max(), linestyle='dashed', alpha=1, color="#ff7f0e")
axs[0][1].set_yticklabels([])
axs[0][1].set_yticks([])
axs[0][1].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[0][1].legend(prop={'size': 20})

axs[0][2].plot(x_gamma, gamma_p, label='prior')
axs[0][2].plot(x_gamma, gamma_2, label='large effect')
axs[0][2].vlines(g_p*s, ymin=0, ymax=1*gamma_p.max(), linestyle='dashed', alpha=1, color="#1f77b4")
axs[0][2].vlines(g_2*s, ymin=0, ymax=1*gamma_2.max(), linestyle='dashed', alpha=1, color="#ff7f0e")
axs[0][2].set_yticklabels([])
axs[0][2].set_yticks([])
axs[0][2].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[0][2].legend(prop={'size': 20})

axs[1][0].plot(x_gamma, gamma_p, label='prior')
axs[1][0].plot(x_gamma, gamma_3, label='large group')
axs[1][0].vlines(g_p*s, ymin=0, ymax=1*gamma_p.max(), linestyle='dashed', alpha=1, color="#1f77b4")
axs[1][0].vlines(g_3*s, ymin=0, ymax=1*gamma_3.max(), linestyle='dashed', alpha=1, color="#ff7f0e")
axs[1][0].set_yticklabels([])
axs[1][0].set_yticks([])
axs[1][0].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[1][0].legend(prop={'size': 20})

axs[1][1].plot(x_gamma, gamma_p, label='prior')
axs[1][1].plot(x_gamma, gamma_4, label='special actor')
axs[1][1].vlines(g_p*s, ymin=0, ymax=1*gamma_p.max(), linestyle='dashed', alpha=1, color="#1f77b4")
axs[1][1].vlines(g_4*s, ymin=0, ymax=1*gamma_4.max(), linestyle='dashed', alpha=1, color="#ff7f0e")
axs[1][1].set_yticklabels([])
axs[1][1].set_yticks([])
axs[1][1].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[1][1].legend(prop={'size': 20})

axs[1][2].plot(x_gamma, gamma_p, label='prior')
axs[1][2].plot(x_gamma, gamma_5, label='large group + effect')
axs[1][2].vlines(g_p*s, ymin=0, ymax=1*gamma_p.max(), linestyle='dashed', alpha=1, color="#1f77b4")
axs[1][2].vlines(g_5*s, ymin=0, ymax=1*gamma_5.max(), linestyle='dashed', alpha=1, color="#ff7f0e")
axs[1][2].set_yticklabels([])
axs[1][2].set_yticks([])
axs[1][2].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[1][2].legend(prop={'size': 20})

for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=18)

plt.show();

# %%
#combine
def gamma_beta(x, a, b, g, s):
    beta_exp = a/(a+b)
    return(beta_exp, gamma.pdf(x, beta_exp*g, scale=s))
           
gb_exp_p, gamma_beta_p = gamma_beta(x_gamma, a_p, b_p, g_p, s)
gb_exp_1_1, gamma_beta_1_1 = gamma_beta(x_gamma, a_1, b_1, g_1, s)
gb_exp_1_3, gamma_beta_1_3 = gamma_beta(x_gamma, a_1, b_1, g_3, s)
gb_exp_1_5, gamma_beta_1_5 = gamma_beta(x_gamma, a_1, b_1, g_5, s)
gb_exp_3_1, gamma_beta_3_1 = gamma_beta(x_gamma, a_3, b_3, g_1, s)
gb_exp_3_3, gamma_beta_3_3 = gamma_beta(x_gamma, a_3, b_3, g_3, s)
gb_exp_3_5, gamma_beta_3_5 = gamma_beta(x_gamma, a_3, b_3, g_5, s)
gb_exp_5_1, gamma_beta_5_1 = gamma_beta(x_gamma, a_5, b_5, g_1, s)
gb_exp_5_3, gamma_beta_5_3 = gamma_beta(x_gamma, a_5, b_5, g_3, s)
gb_exp_5_5, gamma_beta_5_5 = gamma_beta(x_gamma, a_5, b_5, g_5, s)

# %%
#plot it
fig, axs = plt.subplots(nrows=3, ncols=3, sharex=False, figsize=(23, 18))
x_labels = ['', 'nothing happens', 'who cares', 'maybe something', 'actually something', 'big impact', 'nuclear war' ]


axs[0][0].plot(x_gamma, gamma_beta_p, label='combined prior')
axs[0][0].plot(x_gamma, gamma_beta_1_1, label='WE + SI')
axs[0][0].vlines(g_p*s, ymin=0, ymax=1*gamma_p.max(), linestyle='dashed', alpha=1, color="#1f77b4")
axs[0][0].set_yticklabels([])
axs[0][0].set_yticks([])
axs[0][0].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[0][0].legend(prop={'size': 20})

axs[0][1].plot(x_gamma, gamma_beta_p, label='combined prior')
axs[0][1].plot(x_gamma, gamma_beta_1_3, label='WE + LG')
axs[0][1].set_yticklabels([])
axs[0][1].set_yticks([])
axs[0][1].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[0][1].legend(prop={'size': 20})

axs[0][2].plot(x_gamma, gamma_beta_p, label='combined prior')
axs[0][2].plot(x_gamma, gamma_beta_1_5, label='WE + LG & LE')
axs[0][2].set_yticklabels([])
axs[0][2].set_yticks([])
axs[0][2].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[0][2].legend(prop={'size': 20})

axs[1][0].plot(x_gamma, gamma_beta_p, label='combined prior')
axs[1][0].plot(x_gamma, gamma_beta_3_1, label='MM + SI')
axs[1][0].set_yticklabels([])
axs[1][0].set_yticks([])
axs[1][0].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[1][0].legend(prop={'size': 20})

axs[1][1].plot(x_gamma, gamma_beta_p, label='combined prior')
axs[1][1].plot(x_gamma, gamma_beta_3_3, label='MM + LG')
axs[1][1].set_yticklabels([])
axs[1][1].set_yticks([])
axs[1][1].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[1][1].legend(prop={'size': 20})

axs[1][2].plot(x_gamma, gamma_beta_p, label='combined prior')
axs[1][2].plot(x_gamma, gamma_beta_3_5, label='MM + LG & LE')
axs[1][2].set_yticklabels([])
axs[1][2].set_yticks([])
axs[1][2].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[1][2].legend(prop={'size': 20})

axs[2][0].plot(x_gamma, gamma_beta_p, label='combined prior')
axs[2][0].plot(x_gamma, gamma_beta_5_1, label='MM & SM + SI')
axs[2][0].set_yticklabels([])
axs[2][0].set_yticks([])
axs[2][0].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[2][0].legend(prop={'size': 20})

axs[2][1].plot(x_gamma, gamma_beta_p, label='combined prior')
axs[2][1].plot(x_gamma, gamma_beta_5_3, label='MM & SM + LG')
axs[2][1].set_yticklabels([])
axs[2][1].set_yticks([])
axs[2][1].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[2][1].legend(prop={'size': 20})

axs[2][2].plot(x_gamma, gamma_beta_p, label='combined prior')
axs[2][2].plot(x_gamma, gamma_beta_5_5, label='MM & SM + LG & LE')
axs[2][2].set_yticklabels([])
axs[2][2].set_yticks([])
axs[2][2].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[2][2].legend(prop={'size': 20})


for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=18)

plt.show();

# %%
# check out chi2
from scipy.stats import chi2
x_chi2 = np.linspace(0, 25, 250+1)

#prior

c_p = 3
chi2_p = chi2.pdf(x_chi2, c_p)

#small impact
c_1 = c_p + 1
chi2_1 = chi2.pdf(x_chi2, c_1)

#large effect
c_2 = c_p + 5
chi2_2 = chi2.pdf(x_chi2, c_2)

#large group
c_3 = c_p + 7
chi2_3 = chi2.pdf(x_chi2, c_3)

#strong moral concideration
c_4 = c_p + 3
chi2_4 = chi2.pdf(x_chi2, c_4)

#large group + large effect
c_5 = c_2 + c_3 - c_p
chi2_5 = chi2.pdf(x_chi2, c_5)

# %%
#plot it
fig, axs = plt.subplots(nrows=2, ncols=3, sharex=False, figsize=(23, 12))
x_labels = ['', 'nothing happens', 'who cares', 'maybe something', 'actually something', 'big impact', 'nuclear war' ]


axs[0][0].plot(x_chi2, chi2_p, label='prior')
axs[0][0].set_yticklabels([])
axs[0][0].set_yticks([])
axs[0][0].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[0][0].legend(prop={'size': 20})

axs[0][1].plot(x_chi2, chi2_p, label='prior')
axs[0][1].plot(x_chi2, chi2_1, label='small impact')
axs[0][1].set_yticklabels([])
axs[0][1].set_yticks([])
axs[0][1].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[0][1].legend(prop={'size': 20})

axs[0][2].plot(x_chi2, chi2_p, label='prior')
axs[0][2].plot(x_chi2, chi2_2, label='large effect')
axs[0][2].set_yticklabels([])
axs[0][2].set_yticks([])
axs[0][2].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[0][2].legend(prop={'size': 20})

axs[1][0].plot(x_chi2, chi2_p, label='prior')
axs[1][0].plot(x_chi2, chi2_3, label='large group')
axs[1][0].set_yticklabels([])
axs[1][0].set_yticks([])
axs[1][0].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[1][0].legend(prop={'size': 20})

axs[1][1].plot(x_chi2, chi2_p, label='prior')
axs[1][1].plot(x_chi2, chi2_4, label='special actor')
axs[1][1].set_yticklabels([])
axs[1][1].set_yticks([])
axs[1][1].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[1][1].legend(prop={'size': 20})

axs[1][2].plot(x_chi2, chi2_p, label='prior')
axs[1][2].plot(x_chi2, chi2_5, label='large group + effect')
axs[1][2].set_yticklabels([])
axs[1][2].set_yticks([])
axs[1][2].set_xticklabels(x_labels, fontdict={'fontsize':13})
axs[1][2].legend(prop={'size': 20})

for ax in fig.axes:
    plt.sca(ax)
    plt.xticks(rotation=18)

plt.show();
